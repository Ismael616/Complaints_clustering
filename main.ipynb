# %%
from jyquickhelper import add_notebook_menu
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
# ...

# %% [markdown]
# ## import libraries

# %%
import Analysis
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Overview

# %% [markdown]
# ### importing  & viewing

# %%
data=pd.read_csv('Consumer_Complaints.csv',low_memory=False)
data.head()
# Out:
#   Date received                  Product                  Sub-product  \
# 0    07/29/2013            Consumer Loan                 Vehicle loan
# 1    07/29/2013  Bank account or service             Checking account
# 2    07/29/2013  Bank account or service             Checking account
# 3    07/29/2013  Bank account or service             Checking account
# 4    07/29/2013                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub-issue  \
# 0                Managing the loan or lease       NaN
# 1                 Using a debit or ATM card       NaN
# 2   Account opening, closing, or management       NaN
# 3                  Deposits and withdrawals       NaN
# 4  Loan servicing, payments, escrow account       NaN
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# ...

# %% [markdown]
# __some Columns details__
# * Date received : the date the complaints was received
# * Product : The product on which the complaint is about
# * Sub product : More detail about the product concerned by the complaint
# * issue : the proper issue
# * Consummer complaint narrative : details about the complaint by the client
# * company public response : response of the company
# * company : company concerned
# * date sent to company : the date te company received the complaint

# %%
data.shape
# Out:
# (670598, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 670598 entries, 0 to 670597
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date received                 670598 non-null  object
#  1   Product                       670598 non-null  object
#  2   Sub-product                   472396 non-null  object
#  3   Issue                         670598 non-null  object
#  4   Sub-issue                     269868 non-null  object
#  5   Consumer complaint narrative  114704 non-null  object
#  6   Company public response       145197 non-null  object
#  7   Company                       670598 non-null  object
#  8   State                         665293 non-null  object
#  9   ZIP code                      665274 non-null  object
#  10  Tags                          94730 non-null   object
#  11  Consumer consent provided?    208151 non-null  object
# ...

# %% [markdown]
# * only one categorical columns
# * dates columns are of wrong types

# %% [markdown]
# ###  summary statistics

# %%
Analysis.analyse_obj(data)
# Out:
#                                count  unique  \
# Date received                 670598    1818
# Product                       670598      12
# Sub-product                   472396      47
# Issue                         670598      95
# Sub-issue                     269868      68
# Consumer complaint narrative  114704  112690
# Company public response       145197      10
# Company                       670598    3933
# State                         665293      62
# ZIP code                      665274   27889
# Tags                           94730       3
# Consumer consent provided?    208151       4
# Submitted via                 670598       6
# Date sent to company          670598    1767
# Company response to consumer  670598       8
# Timely response?              670598       2
# Consumer disputed?            629179       2
#
#                                                                             top  \
# ...

# %% [markdown]
# * company public responses ,sub_issue , comsummer_complaint narrative , Consummer consent Provided  & account status have high levels of null values

# %% [markdown]
# ## EDA & Wrangling

# %%
data.head()
# Out:
#   Date received                  Product                  Sub-product  \
# 0    07/29/2013            Consumer Loan                 Vehicle loan
# 1    07/29/2013  Bank account or service             Checking account
# 2    07/29/2013  Bank account or service             Checking account
# 3    07/29/2013  Bank account or service             Checking account
# 4    07/29/2013                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub-issue  \
# 0                Managing the loan or lease       NaN
# 1                 Using a debit or ATM card       NaN
# 2   Account opening, closing, or management       NaN
# 3                  Deposits and withdrawals       NaN
# 4  Loan servicing, payments, escrow account       NaN
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# ...

# %%
data_origin=data.copy()
data['Date received']=pd.to_datetime(data['Date received'])
data['Date sent to company']=pd.to_datetime(data['Date sent to company'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 670598 entries, 0 to 670597
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date received                 670598 non-null  datetime64[ns]
#  1   Product                       670598 non-null  object
#  2   Sub-product                   472396 non-null  object
#  3   Issue                         670598 non-null  object
#  4   Sub-issue                     269868 non-null  object
#  5   Consumer complaint narrative  114704 non-null  object
#  6   Company public response       145197 non-null  object
#  7   Company                       670598 non-null  object
#  8   State                         665293 non-null  object
#  9   ZIP code                      665274 non-null  object
#  10  Tags                          94730 non-null   object
#  11  Consumer consent provided?    208151 non-null  object
# ...

# %%
Analysis.analyse_obj(data)
# Out:
#                                count  unique  \
# Product                       670598      12
# Sub-product                   472396      47
# Issue                         670598      95
# Sub-issue                     269868      68
# Consumer complaint narrative  114704  112690
# Company public response       145197      10
# Company                       670598    3933
# State                         665293      62
# ZIP code                      665274   27889
# Tags                           94730       3
# Consumer consent provided?    208151       4
# Submitted via                 670598       6
# Company response to consumer  670598       8
# Timely response?              670598       2
# Consumer disputed?            629179       2
#
#                                                                             top  \
# Product                                                                Mortgage
# ...

# %% [markdown]
# ### dealing with na values and drop unnercessary columns

# %%
data['Consumer disputed?'].value_counts()[:10]
# Out:
# No     496466
# Yes    132713
# Name: Consumer disputed?, dtype: int64

# %% [markdown]
# ###  Data Viz
